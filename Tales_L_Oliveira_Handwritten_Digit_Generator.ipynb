# %% [markdown]
# # Handwritten Digit Generator Web App in Google Colab
#
# **This script will:**
# - 1. Install necessary libraries (PyTorch, Streamlit, pyngrok).
# - 2. Define and train a Conditional DCGAN on the MNIST dataset.
# - 3. Save the trained Generator model.
# - 4. Create a Streamlit web application script.

# %%
# --- 1. Install necessary libraries ---
# This part needs to be run only once.
# !pip install torch torchvision streamlit pillow --quiet

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 59.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 52.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.4 MB/s eta 0:00:00

# %%
# --- 2. Device configuration and Hyperparameters ---
# This line will automatically detect and use a CUDA-enabled GPU (like T4) if available.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Hyperparameters for GAN training
latent_dim = 100
num_classes = 10
image_size = 28
num_epochs = 50 # Reduced for faster demonstration in Colab, consider 100-200 for better quality
batch_size = 128 # Increased for faster training
lr = 0.0002
beta1 = 0.5
# Out:
# Using device: cuda

# %%
# --- 3. Data Transformation and Loading ---
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)) # Normalize to [-1, 1]
])

# MNIST Dataset
print("Downloading MNIST dataset...")
mnist_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
dataloader = torch.utils.data.DataLoader(mnist_dataset, batch_size=batch_size, shuffle=True)
print("MNIST dataset loaded.")
# Out:
# Downloading MNIST dataset...
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 482kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.48MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.46MB/s]
# MNIST dataset loaded.

# %%
#  --- 4. Generator and Discriminator Architectures ---
# Generator model for generating images from latent vectors and digit labels
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # Embedding for conditional input (digit label)
        self.label_emb = nn.Embedding(num_classes, num_classes)

        # Main sequential block of the generator
        self.main = nn.Sequential(
            # Input: (latent_dim + num_classes) x 1 x 1 (concatenated noise and label)
            # From 1x1 to 7x7
            nn.ConvTranspose2d(latent_dim + num_classes, 256, 7, 1, 0, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            # State size: 256 x 7 x 7
            # From 7x7 to 14x14
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            # State size: 128 x 14 x 14
            # From 14x14 to 28x28
            nn.ConvTranspose2d(128, 1, 4, 2, 1, bias=False), # Output 1 channel for grayscale
            nn.Tanh() # Output pixel values in [-1, 1]
            # Output size: 1 x 28 x 28
        )

    def forward(self, noise, labels):
        # Combine noise and label embedding
        # Label embedding is converted to a vector and concatenated with noise
        gen_input = torch.cat((self.label_emb(labels), noise.view(noise.size(0), -1)), -1)
        # Reshape for ConvTranspose2d (batch_size, channels, 1, 1)
        gen_input = gen_input.view(gen_input.size(0), gen_input.size(1), 1, 1)
        return self.main(gen_input)

# Discriminator model for distinguishing real from fake images
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # Embedding for conditional input (digit label)
        self.label_emb = nn.Embedding(num_classes, num_classes)

        # Main sequential block of the discriminator
        self.main = nn.Sequential(
            # Input: (1 + num_classes) x 28 x 28 (after concatenating label)
            nn.Conv2d(1 + num_classes, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # State size: 64 x 14 x 14
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            # State size: 128 x 7 x 7
            nn.Conv2d(128, 256, 3, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            # State size: 256 x 4 x 4
            nn.Conv2d(256, 1, 4, 1, 0, bias=False), # Output 1 channel for binary classification
            nn.Sigmoid() # Output probability in [0, 1]
            # Output size: 1 x 1 x 1
        )

    def forward(self, img, labels):
        # Expand labels to match image dimensions for concatenation
        labels_expanded = self.label_emb(labels).view(labels.size(0), num_classes, 1, 1).repeat(1, 1, image_size, image_size)
        # Concatenate image and expanded label
        d_in = torch.cat((img, labels_expanded), 1)
        return self.main(d_in).view(-1, 1) # Flatten output for BCE loss

# %%
# --- 5. Initialize models and weights ---
netG = Generator().to(device)
netD = Discriminator().to(device)

# Custom weights initialization for DCGAN
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

netG.apply(weights_init)
netD.apply(weights_init)
# Out:
# Discriminator(
#   (label_emb): Embedding(10, 10)
#   (main): Sequential(
#     (0): Conv2d(11, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (9): Sigmoid()
#   )
# )

# %%
# --- 6. Loss function and Optimizers ---
criterion = nn.BCELoss() # Binary Cross-Entropy Loss
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# %%
# --- 7. Training Loop ---
print("\nStarting Training Loop...")
for epoch in range(num_epochs):
    for i, (real_images, labels) in enumerate(dataloader):
        # Move data to the selected device (GPU if available)
        real_images = real_images.to(device)
        labels = labels.to(device)
        batch_size = real_images.size(0)

        # Train Discriminator
        netD.zero_grad()
        # Train with real images
        output_real = netD(real_images, labels).view(-1) # Flatten output for criterion
        errD_real = criterion(output_real, torch.ones_like(output_real))
        errD_real.backward()

        # Generate fake images
        noise = torch.randn(batch_size, latent_dim, 1, 1, device=device)
        fake_labels = torch.randint(0, num_classes, (batch_size,), device=device)
        fake_images = netG(noise, fake_labels)
        # Train with fake images
        output_fake = netD(fake_images.detach(), fake_labels).view(-1) # Detach to prevent G from learning
        errD_fake = criterion(output_fake, torch.zeros_like(output_fake))
        errD_fake.backward()
        errD = errD_real + errD_fake
        optimizerD.step()

        # Train Generator
        netG.zero_grad()
        output_gen = netD(fake_images, fake_labels).view(-1)
        errG = criterion(output_gen, torch.ones_like(output_gen)) # Generator wants D to classify fakes as real
        errG.backward()
        optimizerG.step()

        if i % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}] Batch [{i}/{len(dataloader)}] "
                  f"Loss D: {errD.item():.4f} Loss G: {errG.item():.4f}")

    # Optionally save generator model at certain epochs for checkpoints
    # if (epoch + 1) % 10 == 0:
    #     torch.save(netG.state_dict(), f"generator_epoch_{epoch+1}.pth")
    #     print(f"Generator model saved at epoch {epoch+1}")
# Out:
# Starting Training Loop...
# Epoch [1/50] Batch [0/469] Loss D: 1.5644 Loss G: 1.3757
# Epoch [1/50] Batch [100/469] Loss D: 0.9501 Loss G: 1.1153
# Epoch [1/50] Batch [200/469] Loss D: 1.1492 Loss G: 1.1713
# Epoch [1/50] Batch [300/469] Loss D: 0.8305 Loss G: 1.6863
# Epoch [1/50] Batch [400/469] Loss D: 1.2643 Loss G: 1.3840
# Epoch [2/50] Batch [0/469] Loss D: 0.7887 Loss G: 1.2657
# Epoch [2/50] Batch [100/469] Loss D: 0.9160 Loss G: 1.5377
# Epoch [2/50] Batch [200/469] Loss D: 0.7424 Loss G: 1.2741
# Epoch [2/50] Batch [300/469] Loss D: 1.1483 Loss G: 1.8136
# Epoch [2/50] Batch [400/469] Loss D: 0.8067 Loss G: 1.0559
# Epoch [3/50] Batch [0/469] Loss D: 1.1811 Loss G: 0.9084
# Epoch [3/50] Batch [100/469] Loss D: 0.9174 Loss G: 1.0582
# Epoch [3/50] Batch [200/469] Loss D: 1.4335 Loss G: 0.7474
# Epoch [3/50] Batch [300/469] Loss D: 0.7952 Loss G: 1.3036
# Epoch [3/50] Batch [400/469] Loss D: 1.3171 Loss G: 1.1933
# Epoch [4/50] Batch [0/469] Loss D: 1.3376 Loss G: 1.3377
# Epoch [4/50] Batch [100/469] Loss D: 1.0009 Loss G: 0.9989
# Epoch [4/50] Batch [200/469] Loss D: 0.8005 Loss G: 1.5867
# Epoch [4/50] Batch [300/469] Loss D: 1.2933 Loss G: 1.2441
# Epoch [4/50] Batch [400/469] Loss D: 1.6346 Loss G: 0.9635
# Epoch [5/50] Batch [0/469] Loss D: 1.1659 Loss G: 0.9123
# Epoch [5/50] Batch [100/469] Loss D: 1.1042 Loss G: 1.2971
# Epoch [5/50] Batch [200/469] Loss D: 1.2209 Loss G: 0.9839
# Epoch [5/50] Batch [300/469] Loss D: 0.9992 Loss G: 1.2362
# Epoch [5/50] Batch [400/469] Loss D: 1.4125 Loss G: 0.7761
# Epoch [6/50] Batch [0/469] Loss D: 1.3134 Loss G: 1.0895
# Epoch [6/50] Batch [100/469] Loss D: 1.3497 Loss G: 1.0355
# Epoch [6/50] Batch [200/469] Loss D: 1.8599 Loss G: 0.6731
# Epoch [6/50] Batch [300/469] Loss D: 1.3054 Loss G: 0.7970
# Epoch [6/50] Batch [400/469] Loss D: 1.3463 Loss G: 0.9364
# Epoch [7/50] Batch [0/469] Loss D: 1.3243 Loss G: 1.0279
# Epoch [7/50] Batch [100/469] Loss D: 1.1396 Loss G: 0.6886
# Epoch [7/50] Batch [200/469] Loss D: 1.1091 Loss G: 0.9442
# Epoch [7/50] Batch [300/469] Loss D: 2.1530 Loss G: 1.0840
# Epoch [7/50] Batch [400/469] Loss D: 1.4225 Loss G: 0.6236
# Epoch [8/50] Batch [0/469] Loss D: 1.8572 Loss G: 0.7231
# Epoch [8/50] Batch [100/469] Loss D: 1.2443 Loss G: 0.8717
# Epoch [8/50] Batch [200/469] Loss D: 1.2427 Loss G: 1.1062
# Epoch [8/50] Batch [300/469] Loss D: 1.4196 Loss G: 0.6034
# Epoch [8/50] Batch [400/469] Loss D: 2.0009 Loss G: 0.5625
# Epoch [9/50] Batch [0/469] Loss D: 1.3841 Loss G: 0.8622
# Epoch [9/50] Batch [100/469] Loss D: 1.2742 Loss G: 1.1231
# Epoch [9/50] Batch [200/469] Loss D: 1.5879 Loss G: 0.5906
# Epoch [9/50] Batch [300/469] Loss D: 1.2742 Loss G: 0.7785
# Epoch [9/50] Batch [400/469] Loss D: 1.0852 Loss G: 1.0020
# Epoch [10/50] Batch [0/469] Loss D: 1.6434 Loss G: 0.9668
# Epoch [10/50] Batch [100/469] Loss D: 1.8895 Loss G: 0.5601
# Epoch [10/50] Batch [200/469] Loss D: 1.1961 Loss G: 1.1449
# Epoch [10/50] Batch [300/469] Loss D: 1.4872 Loss G: 0.7458
# Epoch [10/50] Batch [400/469] Loss D: 1.5551 Loss G: 0.8720
# Epoch [11/50] Batch [0/469] Loss D: 1.6037 Loss G: 0.7927
# Epoch [11/50] Batch [100/469] Loss D: 1.3565 Loss G: 1.0122
# Epoch [11/50] Batch [200/469] Loss D: 1.2166 Loss G: 0.7414
# Epoch [11/50] Batch [300/469] Loss D: 1.4136 Loss G: 0.6767
# Epoch [11/50] Batch [400/469] Loss D: 1.6146 Loss G: 0.7754
# Epoch [12/50] Batch [0/469] Loss D: 0.9865 Loss G: 1.0052
# Epoch [12/50] Batch [100/469] Loss D: 1.1590 Loss G: 0.9736
# Epoch [12/50] Batch [200/469] Loss D: 2.1423 Loss G: 0.8261
# Epoch [12/50] Batch [300/469] Loss D: 1.6566 Loss G: 0.9161
# Epoch [12/50] Batch [400/469] Loss D: 1.4448 Loss G: 0.8552
# Epoch [13/50] Batch [0/469] Loss D: 0.7075 Loss G: 1.4150
# Epoch [13/50] Batch [100/469] Loss D: 0.9829 Loss G: 0.9836
# Epoch [13/50] Batch [200/469] Loss D: 1.3094 Loss G: 0.9320
# Epoch [13/50] Batch [300/469] Loss D: 1.0726 Loss G: 0.9512
# Epoch [13/50] Batch [400/469] Loss D: 1.3652 Loss G: 0.8441
# Epoch [14/50] Batch [0/469] Loss D: 1.8703 Loss G: 0.5286
# Epoch [14/50] Batch [100/469] Loss D: 0.9408 Loss G: 0.9623
# Epoch [14/50] Batch [200/469] Loss D: 1.0249 Loss G: 1.0250
# Epoch [14/50] Batch [300/469] Loss D: 1.1261 Loss G: 0.9594
# Epoch [14/50] Batch [400/469] Loss D: 1.4198 Loss G: 1.0095
# Epoch [15/50] Batch [0/469] Loss D: 0.9260 Loss G: 1.0720
# Epoch [15/50] Batch [100/469] Loss D: 1.2266 Loss G: 0.7388
# Epoch [15/50] Batch [200/469] Loss D: 1.6101 Loss G: 0.6304
# Epoch [15/50] Batch [300/469] Loss D: 1.3475 Loss G: 0.6806
# Epoch [15/50] Batch [400/469] Loss D: 1.0394 Loss G: 0.7985
# Epoch [16/50] Batch [0/469] Loss D: 1.0882 Loss G: 1.0595
# Epoch [16/50] Batch [100/469] Loss D: 1.4761 Loss G: 0.5824
# Epoch [16/50] Batch [200/469] Loss D: 1.6170 Loss G: 0.8592
# Epoch [16/50] Batch [300/469] Loss D: 1.3891 Loss G: 0.7131
# Epoch [16/50] Batch [400/469] Loss D: 1.3750 Loss G: 0.8580
# Epoch [17/50] Batch [0/469] Loss D: 1.1280 Loss G: 0.7786
# Epoch [17/50] Batch [100/469] Loss D: 1.5497 Loss G: 0.6944
# Epoch [17/50] Batch [200/469] Loss D: 1.1364 Loss G: 1.1936
# Epoch [17/50] Batch [300/469] Loss D: 1.3088 Loss G: 0.7975
# Epoch [17/50] Batch [400/469] Loss D: 0.9817 Loss G: 1.0743
# Epoch [18/50] Batch [0/469] Loss D: 1.2562 Loss G: 0.8649
# Epoch [18/50] Batch [100/469] Loss D: 1.2554 Loss G: 0.8513
# Epoch [18/50] Batch [200/469] Loss D: 1.6283 Loss G: 0.6208
# Epoch [18/50] Batch [300/469] Loss D: 1.4209 Loss G: 0.8053
# Epoch [18/50] Batch [400/469] Loss D: 1.1579 Loss G: 0.8132
# Epoch [19/50] Batch [0/469] Loss D: 1.1331 Loss G: 0.9827
# Epoch [19/50] Batch [100/469] Loss D: 1.2930 Loss G: 0.8275
# Epoch [19/50] Batch [200/469] Loss D: 1.2056 Loss G: 0.8374
# Epoch [19/50] Batch [300/469] Loss D: 1.0897 Loss G: 1.0516
# Epoch [19/50] Batch [400/469] Loss D: 1.4881 Loss G: 0.8803
# Epoch [20/50] Batch [0/469] Loss D: 1.0014 Loss G: 0.7464
# Epoch [20/50] Batch [100/469] Loss D: 0.9763 Loss G: 0.9602
# Epoch [20/50] Batch [200/469] Loss D: 1.3316 Loss G: 0.7406
# Epoch [20/50] Batch [300/469] Loss D: 1.4509 Loss G: 0.7458
# Epoch [20/50] Batch [400/469] Loss D: 1.7514 Loss G: 1.0031
# Epoch [21/50] Batch [0/469] Loss D: 1.1765 Loss G: 1.0242
# Epoch [21/50] Batch [100/469] Loss D: 0.8062 Loss G: 1.1553
# Epoch [21/50] Batch [200/469] Loss D: 1.3595 Loss G: 0.6930
# Epoch [21/50] Batch [300/469] Loss D: 1.0912 Loss G: 1.1102
# Epoch [21/50] Batch [400/469] Loss D: 1.0790 Loss G: 0.9479
# Epoch [22/50] Batch [0/469] Loss D: 1.4887 Loss G: 0.8368
# Epoch [22/50] Batch [100/469] Loss D: 1.9113 Loss G: 0.5292
# Epoch [22/50] Batch [200/469] Loss D: 0.9609 Loss G: 1.0427
# Epoch [22/50] Batch [300/469] Loss D: 1.4985 Loss G: 0.7259
# Epoch [22/50] Batch [400/469] Loss D: 0.8284 Loss G: 1.1812
# Epoch [23/50] Batch [0/469] Loss D: 1.2277 Loss G: 0.9168
# Epoch [23/50] Batch [100/469] Loss D: 1.2240 Loss G: 0.8007
# Epoch [23/50] Batch [200/469] Loss D: 1.6841 Loss G: 0.6580
# Epoch [23/50] Batch [300/469] Loss D: 1.3341 Loss G: 0.8447
# Epoch [23/50] Batch [400/469] Loss D: 2.1125 Loss G: 0.3989
# Epoch [24/50] Batch [0/469] Loss D: 1.5811 Loss G: 0.7014
# Epoch [24/50] Batch [100/469] Loss D: 1.1028 Loss G: 0.8573
# Epoch [24/50] Batch [200/469] Loss D: 1.3965 Loss G: 0.8597
# Epoch [24/50] Batch [300/469] Loss D: 0.7779 Loss G: 1.2294
# Epoch [24/50] Batch [400/469] Loss D: 1.0196 Loss G: 1.0561
# Epoch [25/50] Batch [0/469] Loss D: 1.7449 Loss G: 0.5193
# Epoch [25/50] Batch [100/469] Loss D: 1.4998 Loss G: 0.6892
# Epoch [25/50] Batch [200/469] Loss D: 1.0448 Loss G: 0.9371
# Epoch [25/50] Batch [300/469] Loss D: 1.0421 Loss G: 0.8773
# Epoch [25/50] Batch [400/469] Loss D: 1.0164 Loss G: 0.8990
# Epoch [26/50] Batch [0/469] Loss D: 1.4859 Loss G: 0.9100
# Epoch [26/50] Batch [100/469] Loss D: 1.2558 Loss G: 0.8586
# Epoch [26/50] Batch [200/469] Loss D: 1.2732 Loss G: 0.8670
# Epoch [26/50] Batch [300/469] Loss D: 1.1139 Loss G: 1.1113
# Epoch [26/50] Batch [400/469] Loss D: 1.6468 Loss G: 0.7192
# Epoch [27/50] Batch [0/469] Loss D: 1.3683 Loss G: 0.7658
# Epoch [27/50] Batch [100/469] Loss D: 1.4665 Loss G: 0.7965
# Epoch [27/50] Batch [200/469] Loss D: 1.4122 Loss G: 0.8975
# Epoch [27/50] Batch [300/469] Loss D: 0.9021 Loss G: 1.2973
# Epoch [27/50] Batch [400/469] Loss D: 0.6162 Loss G: 1.5059
# Epoch [28/50] Batch [0/469] Loss D: 1.7048 Loss G: 0.5088
# Epoch [28/50] Batch [100/469] Loss D: 0.8756 Loss G: 1.1482
# Epoch [28/50] Batch [200/469] Loss D: 1.1622 Loss G: 0.8615
# Epoch [28/50] Batch [300/469] Loss D: 1.8689 Loss G: 0.6099
# Epoch [28/50] Batch [400/469] Loss D: 1.3100 Loss G: 1.0097
# Epoch [29/50] Batch [0/469] Loss D: 1.4621 Loss G: 0.6141
# Epoch [29/50] Batch [100/469] Loss D: 1.3546 Loss G: 0.7827
# Epoch [29/50] Batch [200/469] Loss D: 1.3120 Loss G: 0.7963
# Epoch [29/50] Batch [300/469] Loss D: 1.2636 Loss G: 0.9201
# Epoch [29/50] Batch [400/469] Loss D: 1.2044 Loss G: 0.9161
# Epoch [30/50] Batch [0/469] Loss D: 1.3065 Loss G: 0.7306
# Epoch [30/50] Batch [100/469] Loss D: 0.7643 Loss G: 1.2349
# Epoch [30/50] Batch [200/469] Loss D: 1.4130 Loss G: 1.0213
# Epoch [30/50] Batch [300/469] Loss D: 1.4393 Loss G: 0.9845
# Epoch [30/50] Batch [400/469] Loss D: 1.1556 Loss G: 0.8615
# Epoch [31/50] Batch [0/469] Loss D: 1.2144 Loss G: 0.8549
# Epoch [31/50] Batch [100/469] Loss D: 1.1716 Loss G: 0.9485
# Epoch [31/50] Batch [200/469] Loss D: 1.0300 Loss G: 1.1886
# Epoch [31/50] Batch [300/469] Loss D: 0.7879 Loss G: 1.3804
# Epoch [31/50] Batch [400/469] Loss D: 0.7153 Loss G: 1.2525
# Epoch [32/50] Batch [0/469] Loss D: 1.4633 Loss G: 0.6723
# Epoch [32/50] Batch [100/469] Loss D: 1.0109 Loss G: 1.0059
# Epoch [32/50] Batch [200/469] Loss D: 1.7399 Loss G: 0.6370
# Epoch [32/50] Batch [300/469] Loss D: 1.2774 Loss G: 1.0728
# Epoch [32/50] Batch [400/469] Loss D: 1.1531 Loss G: 1.0268
# Epoch [33/50] Batch [0/469] Loss D: 0.9880 Loss G: 0.9765
# Epoch [33/50] Batch [100/469] Loss D: 0.8379 Loss G: 1.2908
# Epoch [33/50] Batch [200/469] Loss D: 1.3482 Loss G: 0.7414
# Epoch [33/50] Batch [300/469] Loss D: 0.9626 Loss G: 1.2787
# Epoch [33/50] Batch [400/469] Loss D: 0.9212 Loss G: 1.2087
# Epoch [34/50] Batch [0/469] Loss D: 1.3282 Loss G: 0.8877
# Epoch [34/50] Batch [100/469] Loss D: 1.1531 Loss G: 1.0399
# Epoch [34/50] Batch [200/469] Loss D: 1.0481 Loss G: 0.9085
# Epoch [34/50] Batch [300/469] Loss D: 1.4821 Loss G: 0.6635
# Epoch [34/50] Batch [400/469] Loss D: 1.2007 Loss G: 0.9769
# Epoch [35/50] Batch [0/469] Loss D: 1.6184 Loss G: 0.8296
# Epoch [35/50] Batch [100/469] Loss D: 1.2183 Loss G: 0.9211
# Epoch [35/50] Batch [200/469] Loss D: 0.8366 Loss G: 1.6997
# Epoch [35/50] Batch [300/469] Loss D: 1.5906 Loss G: 0.9801
# Epoch [35/50] Batch [400/469] Loss D: 0.9534 Loss G: 1.1579
# Epoch [36/50] Batch [0/469] Loss D: 1.1185 Loss G: 1.1809
# Epoch [36/50] Batch [100/469] Loss D: 0.7928 Loss G: 1.1379
# Epoch [36/50] Batch [200/469] Loss D: 1.4171 Loss G: 1.1409
# Epoch [36/50] Batch [300/469] Loss D: 0.7267 Loss G: 1.7600
# Epoch [36/50] Batch [400/469] Loss D: 1.5357 Loss G: 0.8592
# Epoch [37/50] Batch [0/469] Loss D: 0.6910 Loss G: 1.5320
# Epoch [37/50] Batch [100/469] Loss D: 1.7508 Loss G: 0.7974
# Epoch [37/50] Batch [200/469] Loss D: 1.8261 Loss G: 0.7088
# Epoch [37/50] Batch [300/469] Loss D: 1.7609 Loss G: 0.6658
# Epoch [37/50] Batch [400/469] Loss D: 1.2236 Loss G: 0.8994
# Epoch [38/50] Batch [0/469] Loss D: 0.6193 Loss G: 1.5994
# Epoch [38/50] Batch [100/469] Loss D: 0.4973 Loss G: 2.0083
# Epoch [38/50] Batch [200/469] Loss D: 1.1173 Loss G: 1.6065
# Epoch [38/50] Batch [300/469] Loss D: 0.7625 Loss G: 1.3126
# Epoch [38/50] Batch [400/469] Loss D: 1.0282 Loss G: 1.0474
# Epoch [39/50] Batch [0/469] Loss D: 0.7797 Loss G: 1.1687
# Epoch [39/50] Batch [100/469] Loss D: 0.8483 Loss G: 1.3247
# Epoch [39/50] Batch [200/469] Loss D: 0.7307 Loss G: 1.3336
# Epoch [39/50] Batch [300/469] Loss D: 1.2254 Loss G: 0.9232
# Epoch [39/50] Batch [400/469] Loss D: 1.7283 Loss G: 0.7161
# Epoch [40/50] Batch [0/469] Loss D: 0.6515 Loss G: 1.4649
# Epoch [40/50] Batch [100/469] Loss D: 0.8255 Loss G: 1.2791
# Epoch [40/50] Batch [200/469] Loss D: 0.8064 Loss G: 1.3173
# Epoch [40/50] Batch [300/469] Loss D: 1.2164 Loss G: 0.9181
# Epoch [40/50] Batch [400/469] Loss D: 1.0009 Loss G: 0.9738
# Epoch [41/50] Batch [0/469] Loss D: 0.8301 Loss G: 1.7879
# Epoch [41/50] Batch [100/469] Loss D: 1.0686 Loss G: 1.1457
# Epoch [41/50] Batch [200/469] Loss D: 0.7335 Loss G: 1.1807
# Epoch [41/50] Batch [300/469] Loss D: 1.6434 Loss G: 0.8330
# Epoch [41/50] Batch [400/469] Loss D: 2.3792 Loss G: 0.5592
# Epoch [42/50] Batch [0/469] Loss D: 0.6901 Loss G: 1.1772
# Epoch [42/50] Batch [100/469] Loss D: 0.5253 Loss G: 1.6952
# Epoch [42/50] Batch [200/469] Loss D: 1.2556 Loss G: 1.1521
# Epoch [42/50] Batch [300/469] Loss D: 0.9023 Loss G: 1.3889
# Epoch [42/50] Batch [400/469] Loss D: 1.5853 Loss G: 0.7173
# Epoch [43/50] Batch [0/469] Loss D: 0.9877 Loss G: 1.0221
# Epoch [43/50] Batch [100/469] Loss D: 1.0637 Loss G: 1.1017
# Epoch [43/50] Batch [200/469] Loss D: 1.5281 Loss G: 0.9863
# Epoch [43/50] Batch [300/469] Loss D: 0.9092 Loss G: 1.4240
# Epoch [43/50] Batch [400/469] Loss D: 1.0721 Loss G: 1.1362
# Epoch [44/50] Batch [0/469] Loss D: 0.9225 Loss G: 1.0436
# Epoch [44/50] Batch [100/469] Loss D: 0.8722 Loss G: 1.3190
# Epoch [44/50] Batch [200/469] Loss D: 1.1435 Loss G: 1.1171
# Epoch [44/50] Batch [300/469] Loss D: 1.3821 Loss G: 0.9417
# Epoch [44/50] Batch [400/469] Loss D: 1.1703 Loss G: 1.2769
# Epoch [45/50] Batch [0/469] Loss D: 1.5736 Loss G: 0.8077
# Epoch [45/50] Batch [100/469] Loss D: 1.5223 Loss G: 0.8938
# Epoch [45/50] Batch [200/469] Loss D: 1.4341 Loss G: 0.7369
# Epoch [45/50] Batch [300/469] Loss D: 0.9555 Loss G: 1.1311
# Epoch [45/50] Batch [400/469] Loss D: 1.0099 Loss G: 1.0956
# Epoch [46/50] Batch [0/469] Loss D: 1.1047 Loss G: 1.1555
# Epoch [46/50] Batch [100/469] Loss D: 1.1248 Loss G: 0.9359
# Epoch [46/50] Batch [200/469] Loss D: 1.4420 Loss G: 0.7094
# Epoch [46/50] Batch [300/469] Loss D: 0.6904 Loss G: 1.7766
# Epoch [46/50] Batch [400/469] Loss D: 1.5152 Loss G: 1.0045
# Epoch [47/50] Batch [0/469] Loss D: 2.0273 Loss G: 0.4540
# Epoch [47/50] Batch [100/469] Loss D: 1.0596 Loss G: 1.0350
# Epoch [47/50] Batch [200/469] Loss D: 0.6660 Loss G: 1.6078
# Epoch [47/50] Batch [300/469] Loss D: 0.8208 Loss G: 1.4108
# Epoch [47/50] Batch [400/469] Loss D: 1.1197 Loss G: 1.0776
# Epoch [48/50] Batch [0/469] Loss D: 1.1387 Loss G: 1.3185
# Epoch [48/50] Batch [100/469] Loss D: 1.2112 Loss G: 1.0287
# Epoch [48/50] Batch [200/469] Loss D: 1.5555 Loss G: 0.6465
# Epoch [48/50] Batch [300/469] Loss D: 1.3213 Loss G: 0.8999
# Epoch [48/50] Batch [400/469] Loss D: 1.4781 Loss G: 0.8126
# Epoch [49/50] Batch [0/469] Loss D: 1.3549 Loss G: 0.8455
# Epoch [49/50] Batch [100/469] Loss D: 0.7615 Loss G: 1.3979
# Epoch [49/50] Batch [200/469] Loss D: 0.9072 Loss G: 1.4054
# Epoch [49/50] Batch [300/469] Loss D: 0.9296 Loss G: 1.2081
# Epoch [49/50] Batch [400/469] Loss D: 1.0532 Loss G: 1.3227
# Epoch [50/50] Batch [0/469] Loss D: 0.7489 Loss G: 1.6478
# Epoch [50/50] Batch [100/469] Loss D: 1.1036 Loss G: 1.3227
# Epoch [50/50] Batch [200/469] Loss D: 0.7759 Loss G: 1.3387
# Epoch [50/50] Batch [300/469] Loss D: 1.4963 Loss G: 1.0559
# Epoch [50/50] Batch [400/469] Loss D: 0.8168 Loss G: 1.3604

# %%
# --- 8. Save the final trained Generator model ---
model_save_path = "generator_final.pth"
torch.save(netG.state_dict(), model_save_path)
print(f"Training complete. Final generator model saved to {model_save_path}")
# Out:
# Training complete. Final generator model saved to generator_final.pth

# %%
# --- 9. Create Streamlit Application Script (app.py) ---
# We write the Streamlit app content to a file to be run by 'streamlit run'
streamlit_app_code = f"""
import streamlit as st
import torch
import torch.nn as nn
from PIL import Image
import numpy as np

# Device configuration (must match training device)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Model architecture (must be identical to the trained model's Generator)
latent_dim = {latent_dim}
num_classes = {num_classes}
image_size = {image_size}

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.label_emb = nn.Embedding(num_classes, num_classes)

        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim + num_classes, 256, 7, 1, 0, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 1, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        gen_input = torch.cat((self.label_emb(labels), noise.view(noise.size(0), -1)), -1)
        gen_input = gen_input.view(gen_input.size(0), gen_input.size(1), 1, 1)
        return self.main(gen_input)

# Load the pre-trained generator model
@st.cache_resource # Cache the model loading for efficiency
def load_generator_model(model_path="{model_save_path}"):
    generator = Generator().to(device)
    try:
        generator.load_state_dict(torch.load(model_path, map_location=device))
        generator.eval() # Set to evaluation mode for inference
        st.success(f"Generator model loaded successfully from {{model_path}}")
    except FileNotFoundError:
        st.error(f"Error: Model file not found at {{model_path}}. Please ensure the model is trained and saved.")
        st.stop() # Stop execution if model is not found
    return generator

generator_model = load_generator_model()

# Function to generate images for a given digit
def generate_digit_images(digit, num_images=5):
    with torch.no_grad(): # Disable gradient calculations for inference
        # Generate random noise vectors for diversity
        noise = torch.randn(num_images, latent_dim, 1, 1, device=device)
        # Create labels for the specified digit (all images will be of this digit)
        labels = torch.full((num_images,), digit, dtype=torch.long, device=device)

        # Generate images using the model
        generated_images = generator_model(noise, labels).cpu()

        # Denormalize images from [-1, 1] to [0, 1] for display
        generated_images = (generated_images + 1) / 2

        # Convert to PIL images for display in Streamlit
        pil_images = []
        for i in range(num_images):
            img_tensor = generated_images[i].squeeze(0) # Remove channel dimension (1, 28, 28) -> (28, 28)
            img_np = img_tensor.numpy() # Convert to NumPy array
            # Scale to 0-255 and convert to uint8 for PIL
            img_pil = Image.fromarray((img_np * 255).astype(np.uint8), 'L') # 'L' mode for grayscale
            pil_images.append(img_pil)
    return pil_images

# --- Streamlit UI ---
st.set_page_config(layout="centered", page_title="Handwritten Digit Generator")

st.title("Handwritten Digit Generator")
st.write("Generate 5 diverse images of a handwritten digit (0-9) similar to the MNIST dataset.")

# User input for digit selection
selected_digit = st.selectbox("Select a digit to generate:", options=list(range(10)))

# Button to trigger image generation
if st.button("Generate Images"):
    st.write(f"Generating 5 images for digit: **{{selected_digit}}**...")
    with st.spinner('Generating images...'): # Show a spinner while images are being generated
        images = generate_digit_images(selected_digit)

    # Display images in a grid format
    cols = st.columns(5) # Create 5 columns for the images
    for i, img in enumerate(images):
        with cols[i]:
            st.image(img, caption=f"Digit {{selected_digit}} - Image {{i+1}}", use_column_width=True)
    st.success("Images generated!")

"""

# Write the Streamlit app code to a file
with open("streamlit_app.py", "w") as f:
    f.write(streamlit_app_code)
print("Streamlit app code written to app.py")
# Out:
# Streamlit app code written to app.py
